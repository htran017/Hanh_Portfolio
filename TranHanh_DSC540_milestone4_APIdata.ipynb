# %% [markdown]
# Name: Hanh Tran
#
# Class: DSC 540
#
# Assignment: Milestone 4

# %% [markdown]
# Connecting to an API/Pulling in the Data and Cleaning/Formatting
#
# Perform at least 5 data transformation and/or cleansing steps to your API data. For example:
#
# Replace Headers
#
# Format data into a more readable format
#
# Identify outliers and bad data
#
# Find duplicates
#
# Fix casing or inconsistent values
#
# Conduct Fuzzy Matching

# %% [markdown]
# Register for API
# https://www.eia.gov/opendata/
#
# EIA Data Sets > International Energy Data > CO2 emissions > Emissions
#
# API CALL TO USE:
#
# http://api.eia.gov/category/?api_key=YOUR_API_KEY_HERE&category_id=2622652

# %%
pip install EIA_python
# Out:
# Collecting EIA_python
#   Downloading eia_python-1.22-py3-none-any.whl (3.8 kB)
# Installing collected packages: EIA-python
# Successfully installed EIA-python-1.22
# Note: you may need to restart the kernel to use updated packages.

# %%
import eia

# %%
from eia import api

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import numpy as np
import matplotlib.pyplot as plt
import html5lib
from fuzzywuzzy import fuzz
import re
import ssl
import urllib.request, urllib.parse, urllib.error
import json
# Out:
# C:\Users\hanhk\anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
#store actual apikey in external json file
with open('eiaAPIkeys.json') as f:
    keys=json.load(f)
    eiaapi=keys["APIkey"]

# %%
apikey= eiaapi

# %%
#define the base URL or API endpoint
serviceurl = 'http://api.eia.gov/category/?'
#use the requests library get method to read the HTML from the URL
response = requests.get(serviceurl)

# %%
#create a simple function that checks the http code status is OK, else handles connection errors gracefully
def httpstatus(res):
    if res.status_code==200:
        print('OK, Connection Successful!')
        return 1
    else:
        print('Bad Request')
        return -1

# %%
#check that simple function works
httpstatus(response)
# Out:
# OK, Connection Successful!
# 1

# %%
emissionsURL= 'https://api.eia.gov/category/?api_key='+apikey+'&category_id=2622652'

# %%
emissions = requests.get(emissionsURL)

# %%
emissions_json = emissions.json()

# %%
emissions_json
# Out:
# {'request': {'category_id': 2622652, 'command': 'category'},
#  'category': {'category_id': '2622652',
#   'parent_category_id': '2622644',
#   'name': 'Emissions',
#   'notes': '',
#   'childcategories': [],
#   'childseries': [{'series_id': 'INTL.4008-8-ABW-MMTCD.A',
#     'name': 'CO2 emissions, Aruba, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-AFG-MMTCD.A',
#     'name': 'CO2 emissions, Afghanistan, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-AFRC-MMTCD.A',
#     'name': 'CO2 emissions, Africa, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-AGO-MMTCD.A',
#     'name': 'CO2 emissions, Angola, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-ALB-MMTCD.A',
#     'name': 'CO2 emissions, Albania, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-ARE-MMTCD.A',
#     'name': 'CO2 emissions, United Arab Emirates, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-ARG-MMTCD.A',
#     'name': 'CO2 emissions, Argentina, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-ARM-MMTCD.A',
#     'name': 'CO2 emissions, Armenia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-ASM-MMTCD.A',
#     'name': 'CO2 emissions, American Samoa, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-ASOC-MMTCD.A',
#     'name': 'CO2 emissions, Asia & Oceania, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-ATA-MMTCD.A',
#     'name': 'CO2 emissions, Antarctica, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-ATG-MMTCD.A',
#     'name': 'CO2 emissions, Antigua and Barbuda, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-AUS-MMTCD.A',
#     'name': 'CO2 emissions, Australia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-AUT-MMTCD.A',
#     'name': 'CO2 emissions, Austria, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-AZE-MMTCD.A',
#     'name': 'CO2 emissions, Azerbaijan, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-BDI-MMTCD.A',
#     'name': 'CO2 emissions, Burundi, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-BEL-MMTCD.A',
#     'name': 'CO2 emissions, Belgium, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-BEN-MMTCD.A',
#     'name': 'CO2 emissions, Benin, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-BFA-MMTCD.A',
#     'name': 'CO2 emissions, Burkina Faso, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-BGD-MMTCD.A',
#     'name': 'CO2 emissions, Bangladesh, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-BGR-MMTCD.A',
#     'name': 'CO2 emissions, Bulgaria, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-BHR-MMTCD.A',
#     'name': 'CO2 emissions, Bahrain, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-BHS-MMTCD.A',
#     'name': 'CO2 emissions, The Bahamas, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-BIH-MMTCD.A',
#     'name': 'CO2 emissions, Bosnia and Herzegovina, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-BLR-MMTCD.A',
#     'name': 'CO2 emissions, Belarus, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-BLZ-MMTCD.A',
#     'name': 'CO2 emissions, Belize, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-BMU-MMTCD.A',
#     'name': 'CO2 emissions, Bermuda, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-BOL-MMTCD.A',
#     'name': 'CO2 emissions, Bolivia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-BRA-MMTCD.A',
#     'name': 'CO2 emissions, Brazil, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-BRB-MMTCD.A',
#     'name': 'CO2 emissions, Barbados, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-BRN-MMTCD.A',
#     'name': 'CO2 emissions, Brunei, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-BTN-MMTCD.A',
#     'name': 'CO2 emissions, Bhutan, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-BWA-MMTCD.A',
#     'name': 'CO2 emissions, Botswana, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-CAF-MMTCD.A',
#     'name': 'CO2 emissions, Central African Republic, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-CAN-MMTCD.A',
#     'name': 'CO2 emissions, Canada, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-CHE-MMTCD.A',
#     'name': 'CO2 emissions, Switzerland, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-CHL-MMTCD.A',
#     'name': 'CO2 emissions, Chile, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-CHN-MMTCD.A',
#     'name': 'CO2 emissions, China, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-CIV-MMTCD.A',
#     'name': 'CO2 emissions, Cote d?Ivoire, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-CMR-MMTCD.A',
#     'name': 'CO2 emissions, Cameroon, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-COD-MMTCD.A',
#     'name': 'CO2 emissions, Congo-Kinshasa, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-COG-MMTCD.A',
#     'name': 'CO2 emissions, Congo-Brazzaville, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-COK-MMTCD.A',
#     'name': 'CO2 emissions, Cook Islands, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-COL-MMTCD.A',
#     'name': 'CO2 emissions, Colombia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-COM-MMTCD.A',
#     'name': 'CO2 emissions, Comoros, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-CPV-MMTCD.A',
#     'name': 'CO2 emissions, Cabo Verde, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-CRI-MMTCD.A',
#     'name': 'CO2 emissions, Costa Rica, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-CSAM-MMTCD.A',
#     'name': 'CO2 emissions, Central & South America, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-CSK-MMTCD.A',
#     'name': 'CO2 emissions, Former Czechoslovakia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-CUB-MMTCD.A',
#     'name': 'CO2 emissions, Cuba, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-CYM-MMTCD.A',
#     'name': 'CO2 emissions, Cayman Islands, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-CYP-MMTCD.A',
#     'name': 'CO2 emissions, Cyprus, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-CZE-MMTCD.A',
#     'name': 'CO2 emissions, Czech Republic, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-DDR-MMTCD.A',
#     'name': 'CO2 emissions, Germany, East, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-DEU-MMTCD.A',
#     'name': 'CO2 emissions, Germany, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-DEUW-MMTCD.A',
#     'name': 'CO2 emissions, Germany, West, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-DJI-MMTCD.A',
#     'name': 'CO2 emissions, Djibouti, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-DMA-MMTCD.A',
#     'name': 'CO2 emissions, Dominica, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-DNK-MMTCD.A',
#     'name': 'CO2 emissions, Denmark, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-DOM-MMTCD.A',
#     'name': 'CO2 emissions, Dominican Republic, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-DZA-MMTCD.A',
#     'name': 'CO2 emissions, Algeria, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-ECU-MMTCD.A',
#     'name': 'CO2 emissions, Ecuador, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-EGY-MMTCD.A',
#     'name': 'CO2 emissions, Egypt, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-ERI-MMTCD.A',
#     'name': 'CO2 emissions, Eritrea, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-ESH-MMTCD.A',
#     'name': 'CO2 emissions, Western Sahara, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-ESP-MMTCD.A',
#     'name': 'CO2 emissions, Spain, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-EST-MMTCD.A',
#     'name': 'CO2 emissions, Estonia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-ETH-MMTCD.A',
#     'name': 'CO2 emissions, Ethiopia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-EU27-MMTCD.A',
#     'name': 'CO2 emissions, European Union, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-EURA-MMTCD.A',
#     'name': 'CO2 emissions, Eurasia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-EURO-MMTCD.A',
#     'name': 'CO2 emissions, Europe, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-FIN-MMTCD.A',
#     'name': 'CO2 emissions, Finland, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-FJI-MMTCD.A',
#     'name': 'CO2 emissions, Fiji, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-FLK-MMTCD.A',
#     'name': 'CO2 emissions, Falkland Islands, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-FRA-MMTCD.A',
#     'name': 'CO2 emissions, France, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-FRO-MMTCD.A',
#     'name': 'CO2 emissions, Faroe Islands, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-FSM-MMTCD.A',
#     'name': 'CO2 emissions, Micronesia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-GAB-MMTCD.A',
#     'name': 'CO2 emissions, Gabon, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-GBR-MMTCD.A',
#     'name': 'CO2 emissions, United Kingdom, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-GEO-MMTCD.A',
#     'name': 'CO2 emissions, Georgia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-GHA-MMTCD.A',
#     'name': 'CO2 emissions, Ghana, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-GIB-MMTCD.A',
#     'name': 'CO2 emissions, Gibraltar, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-GIN-MMTCD.A',
#     'name': 'CO2 emissions, Guinea, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-GLP-MMTCD.A',
#     'name': 'CO2 emissions, Guadeloupe, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-GMB-MMTCD.A',
#     'name': 'CO2 emissions, Gambia, The, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-GNB-MMTCD.A',
#     'name': 'CO2 emissions, Guinea-Bissau, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-GNQ-MMTCD.A',
#     'name': 'CO2 emissions, Equatorial Guinea, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-GRC-MMTCD.A',
#     'name': 'CO2 emissions, Greece, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-GRD-MMTCD.A',
#     'name': 'CO2 emissions, Grenada, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-GRL-MMTCD.A',
#     'name': 'CO2 emissions, Greenland, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-GTM-MMTCD.A',
#     'name': 'CO2 emissions, Guatemala, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-GUF-MMTCD.A',
#     'name': 'CO2 emissions, French Guiana, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-GUM-MMTCD.A',
#     'name': 'CO2 emissions, Guam, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-GUY-MMTCD.A',
#     'name': 'CO2 emissions, Guyana, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-HITZ-MMTCD.A',
#     'name': 'CO2 emissions, Hawaiian Trade Zone, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-HKG-MMTCD.A',
#     'name': 'CO2 emissions, Hong Kong, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-HND-MMTCD.A',
#     'name': 'CO2 emissions, Honduras, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-HRV-MMTCD.A',
#     'name': 'CO2 emissions, Croatia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-HTI-MMTCD.A',
#     'name': 'CO2 emissions, Haiti, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-HUN-MMTCD.A',
#     'name': 'CO2 emissions, Hungary, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-IDN-MMTCD.A',
#     'name': 'CO2 emissions, Indonesia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-IND-MMTCD.A',
#     'name': 'CO2 emissions, India, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-IRL-MMTCD.A',
#     'name': 'CO2 emissions, Ireland, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-IRN-MMTCD.A',
#     'name': 'CO2 emissions, Iran, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-IRQ-MMTCD.A',
#     'name': 'CO2 emissions, Iraq, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-ISL-MMTCD.A',
#     'name': 'CO2 emissions, Iceland, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-ISR-MMTCD.A',
#     'name': 'CO2 emissions, Israel, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-ITA-MMTCD.A',
#     'name': 'CO2 emissions, Italy, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-JAM-MMTCD.A',
#     'name': 'CO2 emissions, Jamaica, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-JOR-MMTCD.A',
#     'name': 'CO2 emissions, Jordan, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-JPN-MMTCD.A',
#     'name': 'CO2 emissions, Japan, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-KAZ-MMTCD.A',
#     'name': 'CO2 emissions, Kazakhstan, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-KEN-MMTCD.A',
#     'name': 'CO2 emissions, Kenya, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-KGZ-MMTCD.A',
#     'name': 'CO2 emissions, Kyrgyzstan, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-KHM-MMTCD.A',
#     'name': 'CO2 emissions, Cambodia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-KIR-MMTCD.A',
#     'name': 'CO2 emissions, Kiribati, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-KNA-MMTCD.A',
#     'name': 'CO2 emissions, Saint Kitts and Nevis, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-KOR-MMTCD.A',
#     'name': 'CO2 emissions, South Korea, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-KWT-MMTCD.A',
#     'name': 'CO2 emissions, Kuwait, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-LAO-MMTCD.A',
#     'name': 'CO2 emissions, Laos, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-LBN-MMTCD.A',
#     'name': 'CO2 emissions, Lebanon, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-LBR-MMTCD.A',
#     'name': 'CO2 emissions, Liberia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-LBY-MMTCD.A',
#     'name': 'CO2 emissions, Libya, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-LCA-MMTCD.A',
#     'name': 'CO2 emissions, Saint Lucia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-LKA-MMTCD.A',
#     'name': 'CO2 emissions, Sri Lanka, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-LSO-MMTCD.A',
#     'name': 'CO2 emissions, Lesotho, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-LTU-MMTCD.A',
#     'name': 'CO2 emissions, Lithuania, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-LUX-MMTCD.A',
#     'name': 'CO2 emissions, Luxembourg, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-LVA-MMTCD.A',
#     'name': 'CO2 emissions, Latvia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-MAC-MMTCD.A',
#     'name': 'CO2 emissions, Macau, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-MAR-MMTCD.A',
#     'name': 'CO2 emissions, Morocco, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '19-DEC-19 04.17.12 PM'},
#    {'series_id': 'INTL.4008-8-MDA-MMTCD.A',
#     'name': 'CO2 emissions, Moldova, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-MDG-MMTCD.A',
#     'name': 'CO2 emissions, Madagascar, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-MDV-MMTCD.A',
#     'name': 'CO2 emissions, Maldives, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-MEX-MMTCD.A',
#     'name': 'CO2 emissions, Mexico, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-MIDE-MMTCD.A',
#     'name': 'CO2 emissions, Middle East, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-MKD-MMTCD.A',
#     'name': 'CO2 emissions, North Macedonia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-MLI-MMTCD.A',
#     'name': 'CO2 emissions, Mali, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-MLT-MMTCD.A',
#     'name': 'CO2 emissions, Malta, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-MMR-MMTCD.A',
#     'name': 'CO2 emissions, Burma, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-MNE-MMTCD.A',
#     'name': 'CO2 emissions, Montenegro, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-MNG-MMTCD.A',
#     'name': 'CO2 emissions, Mongolia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-MNP-MMTCD.A',
#     'name': 'CO2 emissions, Northern Mariana Islands, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-MOZ-MMTCD.A',
#     'name': 'CO2 emissions, Mozambique, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-MRT-MMTCD.A',
#     'name': 'CO2 emissions, Mauritania, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-MSR-MMTCD.A',
#     'name': 'CO2 emissions, Montserrat, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-MTQ-MMTCD.A',
#     'name': 'CO2 emissions, Martinique, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-MUS-MMTCD.A',
#     'name': 'CO2 emissions, Mauritius, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-MWI-MMTCD.A',
#     'name': 'CO2 emissions, Malawi, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-MYS-MMTCD.A',
#     'name': 'CO2 emissions, Malaysia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-NAM-MMTCD.A',
#     'name': 'CO2 emissions, Namibia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-NCL-MMTCD.A',
#     'name': 'CO2 emissions, New Caledonia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-NER-MMTCD.A',
#     'name': 'CO2 emissions, Niger, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-NGA-MMTCD.A',
#     'name': 'CO2 emissions, Nigeria, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-NIC-MMTCD.A',
#     'name': 'CO2 emissions, Nicaragua, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-NIU-MMTCD.A',
#     'name': 'CO2 emissions, Niue, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-NLD-MMTCD.A',
#     'name': 'CO2 emissions, Netherlands, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-NLDA-MMTCD.A',
#     'name': 'CO2 emissions, Netherlands Antilles, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-NOAM-MMTCD.A',
#     'name': 'CO2 emissions, North America, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-NOEC-MMTCD.A',
#     'name': 'CO2 emissions, Non-OECD, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-NOR-MMTCD.A',
#     'name': 'CO2 emissions, Norway, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-NPL-MMTCD.A',
#     'name': 'CO2 emissions, Nepal, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-NRU-MMTCD.A',
#     'name': 'CO2 emissions, Nauru, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-NZL-MMTCD.A',
#     'name': 'CO2 emissions, New Zealand, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-OEAO-MMTCD.A',
#     'name': 'CO2 emissions, OECD - Asia And Oceania, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-OECD-MMTCD.A',
#     'name': 'CO2 emissions, OECD, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-OEEU-MMTCD.A',
#     'name': 'CO2 emissions, OECD - Europe, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-OENA-MMTCD.A',
#     'name': 'CO2 emissions, OECD - North America, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-OMN-MMTCD.A',
#     'name': 'CO2 emissions, Oman, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-OPAF-MMTCD.A',
#     'name': 'CO2 emissions, OPEC - Africa, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-OPEC-MMTCD.A',
#     'name': 'CO2 emissions, OPEC, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-OPNO-MMTCD.A',
#     'name': 'CO2 emissions, Non-OPEC, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-OPSA-MMTCD.A',
#     'name': 'CO2 emissions, OPEC - South America, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-PAK-MMTCD.A',
#     'name': 'CO2 emissions, Pakistan, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-PAN-MMTCD.A',
#     'name': 'CO2 emissions, Panama, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-PER-MMTCD.A',
#     'name': 'CO2 emissions, Peru, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-PERG-MMTCD.A',
#     'name': 'CO2 emissions, Persian Gulf, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-PHL-MMTCD.A',
#     'name': 'CO2 emissions, Philippines, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-PNG-MMTCD.A',
#     'name': 'CO2 emissions, Papua New Guinea, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-POL-MMTCD.A',
#     'name': 'CO2 emissions, Poland, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-PRI-MMTCD.A',
#     'name': 'CO2 emissions, Puerto Rico, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-PRK-MMTCD.A',
#     'name': 'CO2 emissions, North Korea, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-PRT-MMTCD.A',
#     'name': 'CO2 emissions, Portugal, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-PRY-MMTCD.A',
#     'name': 'CO2 emissions, Paraguay, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-PSE-MMTCD.A',
#     'name': 'CO2 emissions, Palestinian Territories, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-PYF-MMTCD.A',
#     'name': 'CO2 emissions, French Polynesia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-QAT-MMTCD.A',
#     'name': 'CO2 emissions, Qatar, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-REU-MMTCD.A',
#     'name': 'CO2 emissions, Reunion, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-ROU-MMTCD.A',
#     'name': 'CO2 emissions, Romania, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-RUS-MMTCD.A',
#     'name': 'CO2 emissions, Russia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-RWA-MMTCD.A',
#     'name': 'CO2 emissions, Rwanda, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-SAU-MMTCD.A',
#     'name': 'CO2 emissions, Saudi Arabia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-SCG-MMTCD.A',
#     'name': 'CO2 emissions, Former Serbia and Montenegro, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-SDN-MMTCD.A',
#     'name': 'CO2 emissions, Sudan, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-SEN-MMTCD.A',
#     'name': 'CO2 emissions, Senegal, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-SGP-MMTCD.A',
#     'name': 'CO2 emissions, Singapore, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-SHN-MMTCD.A',
#     'name': 'CO2 emissions, Saint Helena, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-SLB-MMTCD.A',
#     'name': 'CO2 emissions, Solomon Islands, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-SLE-MMTCD.A',
#     'name': 'CO2 emissions, Sierra Leone, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-SLV-MMTCD.A',
#     'name': 'CO2 emissions, El Salvador, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-SOM-MMTCD.A',
#     'name': 'CO2 emissions, Somalia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-SPM-MMTCD.A',
#     'name': 'CO2 emissions, Saint Pierre and Miquelon, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-SRB-MMTCD.A',
#     'name': 'CO2 emissions, Serbia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-SSD-MMTCD.A',
#     'name': 'CO2 emissions, South Sudan, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-STP-MMTCD.A',
#     'name': 'CO2 emissions, Sao Tome and Principe, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-SUN-MMTCD.A',
#     'name': 'CO2 emissions, Former U.S.S.R., Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-SUR-MMTCD.A',
#     'name': 'CO2 emissions, Suriname, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-SVK-MMTCD.A',
#     'name': 'CO2 emissions, Slovakia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-SVN-MMTCD.A',
#     'name': 'CO2 emissions, Slovenia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-SWE-MMTCD.A',
#     'name': 'CO2 emissions, Sweden, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-SWZ-MMTCD.A',
#     'name': 'CO2 emissions, Eswatini, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-SYC-MMTCD.A',
#     'name': 'CO2 emissions, Seychelles, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-SYR-MMTCD.A',
#     'name': 'CO2 emissions, Syria, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-TCA-MMTCD.A',
#     'name': 'CO2 emissions, Turks and Caicos Islands, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-TCD-MMTCD.A',
#     'name': 'CO2 emissions, Chad, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-TGO-MMTCD.A',
#     'name': 'CO2 emissions, Togo, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-THA-MMTCD.A',
#     'name': 'CO2 emissions, Thailand, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-TJK-MMTCD.A',
#     'name': 'CO2 emissions, Tajikistan, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-TKM-MMTCD.A',
#     'name': 'CO2 emissions, Turkmenistan, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-TLS-MMTCD.A',
#     'name': 'CO2 emissions, Timor-Leste, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-TON-MMTCD.A',
#     'name': 'CO2 emissions, Tonga, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-TTO-MMTCD.A',
#     'name': 'CO2 emissions, Trinidad and Tobago, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-TUN-MMTCD.A',
#     'name': 'CO2 emissions, Tunisia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-TUR-MMTCD.A',
#     'name': 'CO2 emissions, Turkey, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-TUV-MMTCD.A',
#     'name': 'CO2 emissions, Tuvalu, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-TWN-MMTCD.A',
#     'name': 'CO2 emissions, Taiwan, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-TZA-MMTCD.A',
#     'name': 'CO2 emissions, Tanzania, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-UGA-MMTCD.A',
#     'name': 'CO2 emissions, Uganda, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-UKR-MMTCD.A',
#     'name': 'CO2 emissions, Ukraine, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-URY-MMTCD.A',
#     'name': 'CO2 emissions, Uruguay, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-USA-MMTCD.A',
#     'name': 'CO2 emissions, United States, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-USIQ-MMTCD.A',
#     'name': 'CO2 emissions, U.S. Pacific Islands, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-USOH-MMTCD.A',
#     'name': 'CO2 emissions, U.S. Territories, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-UZB-MMTCD.A',
#     'name': 'CO2 emissions, Uzbekistan, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-VCT-MMTCD.A',
#     'name': 'CO2 emissions, Saint Vincent/Grenadines, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-VEN-MMTCD.A',
#     'name': 'CO2 emissions, Venezuela, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-VGB-MMTCD.A',
#     'name': 'CO2 emissions, British Virgin Islands, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-VIR-MMTCD.A',
#     'name': 'CO2 emissions, U.S. Virgin Islands, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-VNM-MMTCD.A',
#     'name': 'CO2 emissions, Vietnam, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-VUT-MMTCD.A',
#     'name': 'CO2 emissions, Vanuatu, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-WAK-MMTCD.A',
#     'name': 'CO2 emissions, Wake Island, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-WORL-MMTCD.A',
#     'name': 'CO2 emissions, World, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'},
#    {'series_id': 'INTL.4008-8-WP11-MMTCD.A',
#     'name': 'CO2 emissions, Australia and New Zealand, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '03-DEC-18 09.52.36 AM'},
#    {'series_id': 'INTL.4008-8-WP12-MMTCD.A',
#     'name': 'CO2 emissions, IEO - Africa, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '03-DEC-18 09.52.36 AM'},
#    {'series_id': 'INTL.4008-8-WP13-MMTCD.A',
#     'name': 'CO2 emissions, Brazil, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '03-DEC-18 09.52.36 AM'},
#    {'series_id': 'INTL.4008-8-WP14-MMTCD.A',
#     'name': 'CO2 emissions, Canada, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '03-DEC-18 09.52.36 AM'},
#    {'series_id': 'INTL.4008-8-WP15-MMTCD.A',
#     'name': 'CO2 emissions, China, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '03-DEC-18 09.52.36 AM'},
#    {'series_id': 'INTL.4008-8-WP16-MMTCD.A',
#     'name': 'CO2 emissions, India, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '03-DEC-18 09.52.36 AM'},
#    {'series_id': 'INTL.4008-8-WP17-MMTCD.A',
#     'name': 'CO2 emissions, Japan, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '03-DEC-18 09.52.36 AM'},
#    {'series_id': 'INTL.4008-8-WP18-MMTCD.A',
#     'name': 'CO2 emissions, Mexico and Chile, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '03-DEC-18 09.52.36 AM'},
#    {'series_id': 'INTL.4008-8-WP19-MMTCD.A',
#     'name': 'CO2 emissions, IEO - Middle East, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '03-DEC-18 09.52.36 AM'},
#    {'series_id': 'INTL.4008-8-WP21-MMTCD.A',
#     'name': 'CO2 emissions, IEO OECD - Europe, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '27-FEB-20 04.46.40 PM'},
#    {'series_id': 'INTL.4008-8-WP22-MMTCD.A',
#     'name': 'CO2 emissions, Other Non-OECD - America, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '03-DEC-18 09.52.36 AM'},
#    {'series_id': 'INTL.4008-8-WP23-MMTCD.A',
#     'name': 'CO2 emissions, Other Non-OECD - Asia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '03-DEC-18 09.52.36 AM'},
#    {'series_id': 'INTL.4008-8-WP24-MMTCD.A',
#     'name': 'CO2 emissions, Other Non-OECD - Europe and Eurasia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '27-FEB-20 04.46.40 PM'},
#    {'series_id': 'INTL.4008-8-WP25-MMTCD.A',
#     'name': 'CO2 emissions, Russia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '03-DEC-18 09.52.36 AM'},
#    {'series_id': 'INTL.4008-8-WP26-MMTCD.A',
#     'name': 'CO2 emissions, South Korea, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '03-DEC-18 09.52.36 AM'},
#    {'series_id': 'INTL.4008-8-WP27-MMTCD.A',
#     'name': 'CO2 emissions, United States, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '03-DEC-18 09.52.36 AM'},
#    {'series_id': 'INTL.4008-8-WSM-MMTCD.A',
#     'name': 'CO2 emissions, Samoa, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-XKS-MMTCD.A',
#     'name': 'CO2 emissions, Kosovo, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '20-AUG-20 11.41.44 AM'},
#    {'series_id': 'INTL.4008-8-YEM-MMTCD.A',
#     'name': 'CO2 emissions, Yemen, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-YUG-MMTCD.A',
#     'name': 'CO2 emissions, Former Yugoslavia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-ZAF-MMTCD.A',
#     'name': 'CO2 emissions, South Africa, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '23-JUN-20 02.32.17 PM'},
#    {'series_id': 'INTL.4008-8-ZMB-MMTCD.A',
#     'name': 'CO2 emissions, Zambia, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '13-DEC-19 05.18.55 PM'},
#    {'series_id': 'INTL.4008-8-ZWE-MMTCD.A',
#     'name': 'CO2 emissions, Zimbabwe, Annual',
#     'f': 'A',
#     'units': 'million metric tonnes carbon dioxide',
#     'updated': '08-JUL-20 10.57.31 AM'}]}}

# %%
api_key = "e9184bcad732eeecbfacc5948d59e644"
api = eia.API(api_key)

# %%
# Retrieve Data By Series ID
series_search = api.data_by_series(series="INTL.4008-8-AFRC-MMTCD.A")

for key,value in series_search.items():
    print(key,value)

africa_df = pd.DataFrame(series_search, )
# Out:
# CO2 emissions, Africa, Annual (million metric tonnes carbon dioxide) {'2017  ': 1309.116061772, '2016  ': 1283.288041859, '2015  ': 1277.711311828, '2014  ': 1264.125405746, '2013  ': 1230.728633099, '2012  ': 1175.726351834, '2011  ': 1134.939982557, '2010  ': 1093.542050376, '2009  ': 1050.760118472, '2008  ': 1017.159874587, '2007  ': 1001.69741535, '2006  ': 1010.867138087, '2005  ': 987.974824629, '2004  ': 936.286984205, '2003  ': 916.020687735, '2002  ': 875.536896859, '2001  ': 843.590659017, '2000  ': 823.350414439, '1999  ': 805.432076271, '1998  ': 805.464233528, '1997  ': 785.851951874, '1996  ': 769.816169522, '1995  ': 748.387654851, '1994  ': 720.168428821, '1993  ': 709.440676075, '1992  ': 698.592561348, '1991  ': 691.970549498, '1990  ': 686.286773696, '1989  ': 662.268823994, '1988  ': 649.913248313, '1987  ': 635.000304951, '1986  ': 609.027405282, '1985  ': 592.275599625, '1984  ': 576.563667679, '1983  ': 547.30317855, '1982  ': 519.98539138, '1981  ': 475.892065184, '1980  ': 451.742614174}

# %%
africa_df.head()
# Out:
#         CO2 emissions, Africa, Annual (million metric tonnes carbon dioxide)
# 1980                                           451.742614
# 1981                                           475.892065
# 1982                                           519.985391
# 1983                                           547.303179
# 1984                                           576.563668

# %%
# Retrieve Data By Series ID
series_search = api.data_by_series(series="INTL.4008-8-ASOC-MMTCD.A")

for key,value in series_search.items():
    print(key,value)

asiaoceania_df = pd.DataFrame(series_search, )
# Out:
# CO2 emissions, Asia & Oceania, Annual (million metric tonnes carbon dioxide) {'2017  ': 17937.206434902, '2016  ': 17769.994687289, '2015  ': 17589.644265268, '2014  ': 17596.353457797, '2013  ': 17514.505614129, '2012  ': 16904.846954922, '2011  ': 16016.948254381, '2010  ': 14794.357635672, '2009  ': 13841.109047047, '2008  ': 13086.94049202, '2007  ': 12536.397884627, '2006  ': 12067.955936361, '2005  ': 11287.46142968, '2004  ': 10372.527352305, '2003  ': 9436.555549577, '2002  ': 8626.332700699, '2001  ': 8210.487443368, '2000  ': 7987.501383293, '1999  ': 7606.837819288, '1998  ': 7236.324996232, '1997  ': 7299.906844128, '1996  ': 7255.848666653, '1995  ': 6965.481780847, '1994  ': 6540.042257246, '1993  ': 6154.816072384, '1992  ': 5826.01295822, '1991  ': 5624.14882454, '1990  ': 5733.380183684, '1989  ': 5287.35322469, '1988  ': 5171.997081167, '1987  ': 4811.685243815, '1986  ': 4580.631519943, '1985  ': 4426.382121145, '1984  ': 4301.317538512, '1983  ': 3816.198913241, '1982  ': 3647.879617628, '1981  ': 3632.15514697, '1980  ': 3616.117597956}

# %%
asiaoceania_df.head()
# Out:
#         CO2 emissions, Asia & Oceania, Annual (million metric tonnes carbon dioxide)
# 1980                                          3616.117598
# 1981                                          3632.155147
# 1982                                          3647.879618
# 1983                                          3816.198913
# 1984                                          4301.317539

# %%
# Retrieve Data By Series ID
series_search = api.data_by_series(series="INTL.4008-8-WP11-MMTCD.A")

for key,value in series_search.items():
    print(key,value)

au_df = pd.DataFrame(series_search, )
# Out:
# CO2 emissions, Australia and New Zealand, Annual (million metric tonnes carbon dioxide) {'2016  ': 476.9006025435292, '2015  ': 467.25901685371196, '2014  ': 459.96939892246246, '2013  ': 460.47030799403706, '2012  ': 454.20332871682723, '2011  ': 451.4416438896688}

# %%
# Retrieve Data By Series ID
series_search = api.data_by_series(series="INTL.4008-8-CAN-MMTCD.A")

for key,value in series_search.items():
    print(key,value)

can_df = pd.DataFrame(series_search, )
# Out:
# CO2 emissions, Canada, Annual (million metric tonnes carbon dioxide) {'2017  ': 624.828229547, '2016  ': 607.184297291, '2015  ': 620.65064337, '2014  ': 614.004742084, '2013  ': 613.283255546, '2012  ': 605.866888806, '2011  ': 598.750569856, '2010  ': 595.535675761, '2009  ': 560.817951311, '2008  ': 579.873447808, '2007  ': 604.419636452, '2006  ': 597.449479418, '2005  ': 592.390125542, '2004  ': 592.477892223, '2003  ': 590.865107169, '2002  ': 563.700034621, '2001  ': 561.921045708, '2000  ': 550.533711533, '1999  ': 547.002094213, '1998  ': 524.523516058, '1997  ': 520.251220492, '1996  ': 505.343492136, '1995  ': 493.277182425, '1994  ': 483.301283376, '1993  ': 469.853759629, '1992  ': 470.04766499, '1991  ': 447.19029212, '1990  ': 455.768586695, '1989  ': 479.321625549, '1988  ': 466.848325075, '1987  ': 435.236482229, '1986  ': 416.661224941, '1985  ': 422.429759804, '1984  ': 420.754409938, '1983  ': 373.624092794, '1982  ': 385.052431123, '1981  ': 397.712988561, '1980  ': 421.34998112}

# %%
# Retrieve Data By Series ID
series_search = api.data_by_series(series="INTL.4008-8-CHN-MMTCD.A")

for key,value in series_search.items():
 4858.559891106, '2004  ': 4845.302981445, '2003  ': 4785.792185764, '2002  ': 4681.985328431, '2001  ': 4689.395937436, '2000  ': 4630.737790808, '1999  ': 4555.266621251, '1998  ': 4629.996341578, '1997  ': 4601.133267301, '1996  ': 4646.890003559, '1995  ': 4523.582711879, '1994  ': 4416.975365512, '1993  ': 4440.003416165, '1992  ': 4531.718718539, '1991  ': 4671.261995618, '1990  ': 5004.757520872, '1989  ': 5126.952501161, '1988  ': 5114.543790932, '1987  ': 5151.177889415, '1986  ': 5095.808723253, '1985  ': 4990.917038344, '1984  ': 4861.167509252, '1983  ': 4523.75954001, '1982  ': 4588.508439835, '1981  ': 4563.240313392, '1980  ': 4788.454905458}

# %%
# Retrieve Data By Series ID
series_search = api.data_by_series(series="INTL.4008-8-USA-MMTCD.A")

for key,value in series_search.items():
    print(key,value)

US_df = pd.DataFrame(series_search, )
# Out:
# CO2 emissions, United States, Annual (million metric tonnes carbon dioxide) {'2017  ': 5133.437, '2016  ': 5174.793, '2015  ': 5267.066, '2014  ': 5413.51, '2013  ': 5362.523, '2012  ': 5236.945, '2011  ': 5446.359, '2010  ': 5585.596, '2009  ': 5387.393, '2008  ': 5811.604, '2007  ': 6001.149, '2006  ': 5910.783, '2005  ': 5991.351, '2004  ': 5971.307, '2003  ': 5851.851, '2002  ': 5801.793, '2001  ': 5760.367, '2000  ': 5861.952, '1999  ': 5689.163, '1998  ': 5634.331, '1997  ': 5581.044, '1996  ': 5510.158, '1995  ': 5322.488, '1994  ': 5259.91, '1993  ': 5182.609, '1992  ': 5091.722, '1991  ': 4993.74, '1990  ': 5038.776, '1989  ': 5066.674, '1988  ': 4979.453, '1987  ': 4755.297, '1986  ': 4597.353, '1985  ': 4586.301, '1984  ': 4595.502, '1983  ': 4367.856, '1982  ': 4393.721, '1981  ': 4627.751, '1980  ': 4750.675}

# %%
# Retrieve Data By Series ID
series_search = api.data_by_series(series="INTL.4008-8-SUN-MMTCD.A")

for key,value in series_search.items():
    print(key,value)

RUS_df = pd.DataFrame(series_search, )
# Out:
# CO2 emissions, Former U.S.S.R., Annual (million metric tonnes carbon dioxide) {'2017  ': '--', '2016  ': '--', '2015  ': '--', '2014  ': '--', '2013  ': '--', '2012  ': '--', '2011  ': '--', '2010  ': '--', '2009  ': '--', '2008  ': '--', '2007  ': '--', '2006  ': '--', '2005  ': '--', '2004  ': '--', '2003  ': '--', '2002  ': '--', '2001  ': '--', '2000  ': '--', '1999  ': '--', '1998  ': '--', '1997  ': '--', '1996  ': '--', '1995  ': '--', '1994  ': '--', '1993  ': '--', '1992  ': '--', '1991  ': 3944.56951542, '1990  ': 4327.414643068, '1989  ': 4186.252614084, '1988  ': 4282.779575009, '1987  ': 4203.179447542, '1986  ': 4143.730267938, '1985  ': 3993.021317937, '1984  ': 3869.572625945, '1983  ': 3735.655096964, '1982  ': 3702.116460425, '1981  ': 3579.222544175, '1980  ': 3561.517210212}

# %%
# Retrieve Data By Series ID
series_search = api.data_by_series(series="INTL.4008-8-IND-MMTCD.A")

for key,value in series_search.items():
    print(key,value)

IN_df = pd.DataFrame(series_search, )
# Out:
# CO2 emissions, India, Annual (million metric tonnes carbon dioxide) {'2017  ': 2312.061218862, '2016  ': 2237.148562192, '2015  ': 2177.981891527, '2014  ': 2092.365758495, '2013  ': 1944.444971776, '2012  ': 1905.228814434, '2011  ': 1677.352792451, '2010  ': 1604.543494104, '2009  ': 1497.486494389, '2008  ': 1411.061330366, '2007  ': 1368.379922707, '2006  ': 1259.36055197, '2005  ': 1169.398363225, '2004  ': 1119.95641205, '2003  ': 1014.048346774, '2002  ': 993.931702371, '2001  ': 945.964699297, '2000  ': 922.563072813, '1999  ': 884.6787127, '1998  ': 839.484454222, '1997  ': 818.953296455, '1996  ': 782.663781032, '1995  ': 745.806810519, '1994  ': 689.708545086, '1993  ': 646.927392381, '1992  ': 617.732919442, '1991  ': 581.054459481, '1990  ': 548.64209131, '1989  ': 515.373742932, '1988  ': 488.86610388, '1987  ': 449.983082972, '1986  ': 417.367851353, '1985  ': 391.389288544, '1984  ': 367.63671597, '1983  ': 341.684036875, '1982  ': 322.590345745, '1981  ': 306.829835267, '1980  ': 271.466648305}

# %%
# Retrieve Data By Series ID
series_search = api.data_by_series(series="INTL.4008-8-MIDE-MMTCD.A")

for key,value in series_search.items():
    print(key,value)

ME_df = pd.DataFrame(series_search, )
# Out:
# CO2 emissions, Middle East, Annual (million metric tonnes carbon dioxide) {'2017  ': 2217.395677206, '2016  ': 2141.422804592, '2015  ': 2105.329606629, '2014  ': 2073.963529397, '2013  ': 2011.162102764, '2012  ': 1976.749297443, '2011  ': 1877.347117373, '2010  ': 1786.833752652, '2009  ': 1692.561491036, '2008  ': 1583.043594072, '2007  ': 1404.276405284, '2006  ': 1447.43777183, '2005  ': 1399.296499908, '2004  ': 1306.322628059, '2003  ': 1217.494207475, '2002  ': 1155.482158835, '2001  ': 1094.054266775, '2000  ': 1069.610419227, '1999  ': 1027.30376575, '1998  ': 990.754005306, '1997  ': 959.160234156, '1996  ': 880.332502301, '1995  ': 855.66671211, '1994  ': 843.336171898, '1993  ': 800.308019221, '1992  ': 765.606461756, '1991  ': 703.016229845, '1990  ': 695.109300153, '1989  ': 688.007335525, '1988  ': 652.289888787, '1987  ': 620.907085721, '1986  ': 586.894340586, '1985  ': 541.171415514, '1984  ': 494.221352494, '1983  ': 457.420599, '1982  ': 405.074019451, '1981  ': 387.935334311, '1980  ': 369.922419056}

# %%
country_df = pd.concat([au_df, can_df, CHN_df, southAmerica_df, eur_df, US_df, RUS_df, IN_df, ME_df], axis=1)

# %%
country_df
# Out:
#         CO2 emissions, Australia and New Zealand, Annual (million metric tonnes carbon dioxide)  \
# 2011                                           451.441644
# 2012                                           454.203329
# 2013                                           460.470308
# 2014                                           459.969399
# 2015                                           467.259017
# 2016                                           476.900603
# 1980                                                  NaN
# 1981                                                  NaN
# 1982                                                  NaN
# 1983                                                  NaN
# 1984                                                  NaN
# 1985                                                  NaN
# 1986                                                  NaN
# 1987                                                  NaN
# 1988                                                  NaN
# 1989                                                  NaN
# 1990                                                  NaN
# 1991                                                  NaN
                           'CO2 emissions, Middle East, Annual (million metric tonnes carbon dioxide)': 'CO2 emissions, Middle East'}, inplace=True)
country_df.head()
# Out:
#         CO2 emissions, AU&NZ  CO2 emissions, Canada  CO2 emissions, China  \
# 2011              451.441644             598.750570           9832.278194
# 2012              454.203329             605.866889          10362.203903
# 2013              460.470308             613.283256          10801.773420
# 2014              459.969399             614.004742          10701.496086
# 2015              467.259017             620.650643          10508.330407
#
#         CO2 emissions, South America  \
# 2011                     1287.033493
# 2012                     1344.819833
# 2013                     1368.346994
# 2014                     1409.948165
# 2015                     1507.385834
#
#         CO2 emissions, Europe, Annual (million metric tonnes carbon dioxide)  \
# 2011                                          4510.229004
# 2012                                          4449.596095
# 2013                                          4367.859197
# 2014                                          4219.535869
# 2015                                          4277.971212
#
#         CO2 emissions, US CO2 emissions, Russia  CO2 emissions, India  \
# 2011             5446.359                    --           1677.352792
# 2012             5236.945                    --           1905.228814
# 2013             5362.523                    --           1944.444972
# 2014             5413.510                    --           2092.365758
# 2015             5267.066                    --           2177.981892
#
#         CO2 emissions, Middle East
# 2011                   1877.347117
# 2012                   1976.749297
# 2013                   2011.162103
# 2014                   2073.963529
# 2015                   2105.329607

# %%
print(country_df.columns.values.tolist())
# Out:
# ['CO2 emissions, AU&NZ', 'CO2 emissions, Canada', 'CO2 emissions, China', 'CO2 emissions, South America', 'CO2 emissions, Europe, Annual (million metric tonnes carbon dioxide)', 'CO2 emissions, US', 'CO2 emissions, Russia', 'CO2 emissions, India', 'CO2 emissions, Middle East']

# %%
print(country_df.keys())
# Out:
# Index(['CO2 emissions, AU&NZ', 'CO2 emissions, Canada', 'CO2 emissions, China',
#        'CO2 emissions, South America',
#        'CO2 emissions, Europe, Annual (million metric tonnes carbon dioxide)',
#        'CO2 emissions, US', 'CO2 emissions, Russia', 'CO2 emissions, India',
#        'CO2 emissions, Middle East'],
#       dtype='object')

# %%
#remove duplicates
country_df.duplicated(subset=None, keep='first')
# Out:
# 2011      False
# 2012      False
# 2013      False
# 2014      False
# 2015      False
# 2016      False
# 1980      False
# 1981      False
# 1982      False
# 1983      False
# 1984      False
# 1985      False
# 1986      False
# 1987      False
# 1988      False
# 1989      False
# 1990      False
# 1991      False
# 1992      False
# 1993      False
# 1994      False
# 1995      False
# 1996      False
# 1997      False
# 1998      False
# 1999      False
# 2000      False
# 2001      False
# 2002      False
# 2003      False
# 2004      False
# 2005      False
# 2006      False
# 2007      False
# 2008      False
# 2009      False
# 2010      False
# 2017      False
# dtype: bool

# %%
country_df.shape
# Out:
# (38, 9)

# %%
country_df.drop_duplicates()
# Out:
#         CO2 emissions, AU&NZ  CO2 emissions, Canada  CO2 emissions, China  \
# 2011              451.441644             598.750570           9832.278194
# 2012              454.203329             605.866889          10362.203903
# 2013              460.470308             613.283256          10801.773420
# 2014              459.969399             614.004742          10701.496086
# 2015              467.259017             620.650643          10508.330407
# 2016              476.900603             607.184297          10501.798342
# 1980                     NaN             421.349981           1664.569001
# 1981                     NaN             397.712989           1648.030815
# 1982                     NaN             385.052431           1710.955585
# 1983                     NaN             373.624093           1810.848455
# 2010                                          4600.675001
# 2017                                          4364.508647
#
#         CO2 emissions, US CO2 emissions, Russia  CO2 emissions, India  \
# 2011             5446.359                    --           1677.352792
# 2012             5236.945                    --           1905.228814
# 2013             5362.523                    --           1944.444972
# 2014             5413.510                    --           2092.365758
# 2015             5267.066                    --           2177.981892
# 2016             5174.793                    --           2237.148562
# 1980             4750.675               3561.52            271.466648
# 1981             4627.751               3579.22            306.829835
# 1982             4393.721               3702.12            322.590346
# 1983             4367.856               3735.66            341.684037
# 1984             4595.502               3869.57            367.636716
# 1985             4586.301               3993.02            391.389289
# 1986             4597.353               4143.73            417.367851
# 1987             4755.297               4203.18            449.983083
# 1988             4979.453               4282.78            488.866104
# 1989             5066.674               4186.25            515.373743
# 1990             5038.776               4327.41            548.642091
# 1991             4993.740               3944.57            581.054459
# 1992             5091.722                    --            617.732919
# 1993             5182.609                    --            646.927392
# 1994             5259.910                    --            689.708545
# 1995             5322.488                    --            745.806811
# 1996             5510.158                    --            782.663781
# 1997             5581.044                    --            818.953296
# 1998             5634.331                    --            839.484454
# 1999             5689.163                    --            884.678713
# 2000             5861.952                    --            922.563073
# 2001             5760.367                    --            945.964699
# 2002             5801.793                    --            993.931702
# 2003             5851.851                    --           1014.048347
# 2004             5971.307                    --           1119.956412
# 2005             5991.351                    --           1169.398363
# 2006             5910.783                    --           1259.360552
# 2007             6001.149                    --           1368.379923
# 2008             5811.604                    --           1411.061330
# 2009             5387.393                    --           1497.486494
# 2010             5585.596                    --           1604.543494
# 2017             5133.437                    --           2312.061219
#
#         CO2 emissions, Middle East
# 2011                   1877.347117
# 2012                   1976.749297
# 2013                   2011.162103
# 2014                   2073.963529
# 2015                   2105.329607
# 2016                   2141.422805
# 1980                    369.922419
# 1981                    387.935334
# 1982                    405.074019
# 1983                    457.420599
# 1984                    494.221352
# 1985                    541.171416
# 1986                    586.894341
# 1987                    620.907086
# 1988                    652.289889
# 1989                    688.007336
# 1990                    695.109300
# 1991                    703.016230
# 1992                    765.606462
# 1993                    800.308019
# 1994                    843.336172
# 1995                    855.666712
# 1996                    880.332502
# 1997                    959.160234
# 1998                    990.754005
# 1999                   1027.303766
# 2000                   1069.610419
# 2001                   1094.054267
# 2002                   1155.482159
# 2003                   1217.494207
# 2004                   1306.322628
# 2005                   1399.296500
# 2006                   1447.437772
# 2007                   1404.276405
# 2008                   1583.043594
# 2009                   1692.561491
# 2010                   1786.833753
# 2017                   2217.395677

# %%
country_df.shape
# Out:
# (38, 9)

# %%
#find missing values, Australia is lacking data from earlier years
country_df.isna().sum()
# Out:
# CO2 emissions, AU&NZ                                                    32
# CO2 emissions, Canada                                                    0
# CO2 emissions, China                                                     0
# CO2 emissions, South America                                             0
# CO2 emissions, Europe, Annual (million metric tonnes carbon dioxide)     0
# CO2 emissions, US                                                        0
# CO2 emissions, Russia                                                    0
# CO2 emissions, India                                                     0
# CO2 emissions, Middle East                                               0
# dtype: int64

# %%
#conduct fuzzy matching on string data
fuzz.ratio('Africa', 'Africa')
# Out:
# 100

# %%
country_df.to_csv('emissions.csv')
